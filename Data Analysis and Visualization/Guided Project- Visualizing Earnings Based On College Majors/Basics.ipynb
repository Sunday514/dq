# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads = pd.read_csv("recent-grads.csv")
print(recent_grads.iloc[0])
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
print(recent_grads.describe())
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print(raw_data_count)
print(cleaned_data_count)
# Out:
# 173
# 172

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter")
plt.show()

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter")
plt.show()

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter")
plt.show()

# %%
recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter")
plt.show()

# %%
recent_grads.plot(x="Men", y="Median", kind="scatter")
plt.show()

# %%
recent_grads.plot(x="Women", y="Median", kind="scatter")
plt.show()

# %% [markdown]
# Students's income of different majors do not seem relevent to popularity, share of women, or the number of full-time employees.

# %%
recent_grads["Sample_size"].plot(kind="hist")

# %%
recent_grads["Median"].plot(kind="hist")

# %%
recent_grads["Employed"].plot(kind="hist")

# %%
recent_grads["Full_time"].plot(kind="hist")

# %%
recent_grads["ShareWomen"].plot(kind="hist")

# %%
recent_grads["Unemployment_rate"].plot(kind="hist")

# %%
recent_grads["Men"].plot(kind="hist")

# %%
recent_grads["Women"].plot(kind="hist")

# %% [markdown]
# 18 percent of majors are predominantly male.
# 25 percent of majors are predominantly female.
# The most common median salary range is 30000~40000.

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f96b85b69b0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9674337ba8>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Employed", "Median"]], figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9674202438>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9674094d30>]], dtype=object)

# %%
sort_paying = recent_grads.sort_values(["Median"])
sort_paying[0:10].plot.bar(x="Median", y="ShareWomen")

# %%
sort_paying = recent_grads.sort_values(["Median"])
sort_paying[-10:].plot.bar(x="Median", y="ShareWomen")

# %%
sort_paying = recent_grads.sort_values(["Median"])
sort_paying[0:10].plot.bar(x="Median", y="Unemployment_rate")

# %%
sort_paying = recent_grads.sort_values(["Median"])
sort_paying[-10:].plot.bar(x="Median", y="Unemployment_rate")
